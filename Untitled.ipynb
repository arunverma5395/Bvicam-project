# %%
from tpot import TPOTClassifier
from tpot import TPOTRegressor
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from autoviml.Auto_ViML import Auto_ViML
import joblib

def tpotClassifier(train_data, target_value):
    classifier = TPOTClassifier()
    X_train, X_test, y_train, y_test = train_test_split(train_data, train_data[target_value],
                                                        train_size=0.75, test_size=0.25)
    classifier.fit(X_train, y_train)
    score = classifier.score(X_test, y_test)
    classifier.export('my_pipeline.py')
    return classifier, score


def tpotRegressor(train_data, target_value):
    regressor = TPOTRegressor()
    if (target_value in train_data.columns):
        X_train, X_test, y_train, y_test = train_test_split(train_data, train_data[target_value],
                                                            train_size=0.75, test_size=0.25)
        regressor.fit(X_train, y_train)
        score = regressor.score(X_test, y_test)
        regressor.export('my_pipeline.py')
        return regressor, score
    else:
        print("error") 


def autoviml(train_data, target_value, reducer=True, verbosity=0):
    X_train, X_test, y_train, y_test = train_test_split(train_data, train_data[target_value],train_size=0.75, test_size=0.25)
    viml = Auto_ViML(X_train, target_value, X_test,
                     hyper_param='GS', verbose=verbosity, feature_reduction=reducer)
#     score = accuracy_score(y_train, y_test)
    return viml

# %%
import pandas as pd

# %%
data = pd.read_csv('headbrain.csv')

# %%
vi = Auto_ViML(X_train,'Brain Weight(grams)',X_test)
# Out:
# Train (Size: 177,4) has Single_Label with target: ['Brain Weight(grams)']
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     3 Predictors classified...
#         This does not include the Target column(s)
#     No variables removed since no ID or low-information variables found in data set
# No GPU available on this device
# Test data has no missing values...
# ############## F E A T U R E   S E L E C T I O N  ####################
# Trying Feature Selection among 3 numeric variables...
#     No variables were removed since no highly correlated variables found in data
# Regression problem: Started with 3 variables
#     After variable removal, 3 predictors left...
#     No Categorical feature selection since 0 categorical feature(s)...
# ############## F E A T U R E   S E L E C T I O N  ####################
# Trying Feature Selection among 3 numeric variables...
#     No variables were removed since no highly correlated variables found in data
#     Adding 0 categorical variables to reduced numeric variables  of 3
# Current number of predictors = 3
#     Finding Important Features using Boosted Trees algorithm...
#         using 3 variables...
# [16:57:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#         using 1 variables...
# [16:57:33] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Found 3 important features
# Starting Feature Engineering now...
#     No Entropy Binning specified or there are no numeric vars in data set to Bin
# ###############  M O D E L   B U I L D I N G ####################
# Rows in Train data set = 159
#   Features in Train data set = 3
#     Rows in held-out data set = 18
# Finding Best Model and Hyper Parameters for Target: Brain Weight(grams)...
# CPU Count = 4 in this device
# Using Linear Model, Estimated Training time = 0.0 mins
#     Actual training time (in seconds): 10
# ###########  S I N G L E  M O D E L   R E S U L T S #################
# 5-fold Cross Validation rmse Score = 71.4165
#     Best Parameters for Model = {'alpha': 9.182542835656282}
# ########################################################
# Linear Model Prediction Results on Held Out CV Data Set:
#     MAE = 73.7289
#     MAPE = 6%
#     RMSE = 83.9453
#     MAE as % std dev of Actuals = 69.4%
#     Normalized RMSE (% of MinMax of Actuals) = 17%
#     Normalized RMSE (% of Std Dev of Actuals) = 79%
# ################# E N S E M B L E  M O D E L  ##################
# Completed Ensemble predictions on held out data
#     MAE = 73.8095
#     MAPE = 6%
#     RMSE = 83.4080
#     MAE as % std dev of Actuals = 69.5%
#     Normalized RMSE (% of MinMax of Actuals) = 17%
#     Normalized RMSE (% of Std Dev of Actuals) = 79%
# After multiple models, Ensemble Model Results:
#     RMSE Score = 83.40797
# ########################################################
# Ensembling Models is better than Single Model for this data set.
# No evaluation metrics plot available for this model
#     Time taken for this Target (in seconds) = 12
# ############### P R E D I C T I O N  O N  T E S T  #################
#     Time taken for this Target (in seconds) = 12
# Training model on complete Train data and Predicting using give Test Data...
#     No Entropy Binning specified or there are no numeric vars in data set to Bin
# Actual Training time taken in seconds = 0
# Completed Ensemble predictions on held out data
#     Saving predictions to ./Brain Weight(grams)/Brain Weight(grams)_Regression_test_modified.csv
#     Saving predictions to ./Brain Weight(grams)/Brain Weight(grams)_Regression_submission.csv
#     Saving predictions to ./Brain Weight(grams)/Brain Weight(grams)_Regression_train_modified.csv
# ###############  C O M P L E T E D  ################
# Time Taken in mins = 0.2 for the Entire Process

# %%
model = autoviml(data,'Brain Weight(grams)')
# Out:
# Train (Size: 177,4) has Single_Label with target: ['Brain Weight(grams)']
# ############## C L A S S I F Y I N G  V A R I A B L E S  ####################
# Classifying variables in data set...
#     3 Predictors classified...
#         This does not include the Target column(s)
#     No variables removed since no ID or low-information variables found in data set
# No GPU available on this device
# Test data has no missing values...
# ############## F E A T U R E   S E L E C T I O N  ####################
# Trying Feature Selection among 3 numeric variables...
#     No variables were removed since no highly correlated variables found in data
# Regression problem: Started with 3 variables
#     After variable removal, 3 predictors left...
#     No Categorical feature selection since 0 categorical feature(s)...
# ############## F E A T U R E   S E L E C T I O N  ####################
# Trying Feature Selection among 3 numeric variables...
#     No variables were removed since no highly correlated variables found in data
#     Adding 0 categorical variables to reduced numeric variables  of 3
# Current number of predictors = 3
#     Finding Important Features using Boosted Trees algorithm...
#         using 3 variables...
# [17:08:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#         using 1 variables...
# [17:08:22] WARNING: /workspace/src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# Found 3 important features
# Starting Feature Engineering now...
#     No Entropy Binning specified or there are no numeric vars in data set to Bin
# ###############  M O D E L   B U I L D I N G ####################
# Rows in Train data set = 159
#   Features in Train data set = 3
#     Rows in held-out data set = 18
# Finding Best Model and Hyper Parameters for Target: Brain Weight(grams)...
# CPU Count = 4 in this device
# Using Linear Model, Estimated Training time = 0.0 mins
#     Actual training time (in seconds): 8
# ###########  S I N G L E  M O D E L   R E S U L T S #################
# 5-fold Cross Validation rmse Score = 69.1781
#     Best Parameters for Model = {'alpha': 7.94145171902934}
# ########################################################
# Linear Model Prediction Results on Held Out CV Data Set:
#     MAE = 79.1990
#     MAPE = 6%
#     RMSE = 103.7932
#     MAE as % std dev of Actuals = 49.0%
#     Normalized RMSE (% of MinMax of Actuals) = 16%
#     Normalized RMSE (% of Std Dev of Actuals) = 64%
# ################# E N S E M B L E  M O D E L  ##################
# Completed Ensemble predictions on held out data
#     MAE = 78.0023
#     MAPE = 6%
#     RMSE = 101.0125
#     MAE as % std dev of Actuals = 48.3%
#     Normalized RMSE (% of MinMax of Actuals) = 16%
#     Normalized RMSE (% of Std Dev of Actuals) = 63%
# After multiple models, Ensemble Model Results:
#     RMSE Score = 101.01252
# ########################################################
# Ensembling Models is better than Single Model for this data set.
# No evaluation metrics plot available for this model
#     Time taken for this Target (in seconds) = 10
# ############### P R E D I C T I O N  O N  T E S T  #################
#     Time taken for this Target (in seconds) = 10
# Training model on complete Train data and Predicting using give Test Data...
#     No Entropy Binning specified or there are no numeric vars in data set to Bin
# Actual Training time taken in seconds = 0
# Completed Ensemble predictions on held out data
#     Saving predictions to ./Brain Weight(grams)/Brain Weight(grams)_Regression_test_modified.csv
#     Saving predictions to ./Brain Weight(grams)/Brain Weight(grams)_Regression_submission.csv
#     Saving predictions to ./Brain Weight(grams)/Brain Weight(grams)_Regression_train_modified.csv
# ###############  C O M P L E T E D  ################
# Time Taken in mins = 0.2 for the Entire Process

# %%
joblib.dump()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-76-65a00f5fee8a> in <module>
# ----> 1 joblib.dump()
#
# TypeError: dump() missing 2 required positional arguments: 'value' and 'filename'
